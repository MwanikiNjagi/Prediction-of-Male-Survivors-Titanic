# %%
import config
import pandas as pd
import seaborn as sns

df = pd.read_csv(config.preprocessed_train)
df.head(60)
# Out:
#     Survived  Pclass   Age  SibSp  Parch      Fare
# 0          0       3  22.0      1      0    7.2500
# 1          1       1  38.0      1      0   71.2833
# 2          1       3  26.0      0      0    7.9250
# 3          1       1  35.0      1      0   53.1000
# 4          0       3  35.0      0      0    8.0500
# 5          0       3  28.0      0      0    8.4583
# 6          0       1  54.0      0      0   51.8625
# 7          0       3   2.0      3      1   21.0750
# 8          1       3  27.0      0      2   11.1333
# 9          1       2  14.0      1      0   30.0708
# 10         1       3   4.0      1      1   16.7000
# 11         1       1  58.0      0      0   26.5500
# 12         0       3  20.0      0      0    8.0500
# 13         0       3  39.0      1      5   31.2750
# 14         0       3  14.0      0      0    7.8542
# 15         1       2  55.0      0      0   16.0000
# 16         0       3   2.0      4      1   29.1250
# ...

# %%
sns.boxplot(df.Age)
sns.displot(df.Age)
# Out:
# /home/mwanikii/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
